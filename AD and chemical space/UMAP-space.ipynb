# %%
import pandas as pd
import numpy as np
import chemplot as cp
from chemplot import Plotter
from bokeh.io import output_notebook
import matplotlib.pyplot as plt
import seaborn as sns

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f768ad17-9a62-4763-bf2b-e640e1e63427">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # TM-60 and CM-60 UMAPs

# %%
data = pd.read_csv(r'M:\ML_scripts\chemplot\tobramycin_full_labelled.csv').drop(columns=['Unnamed: 0'])          # full meaning both training and testing data (for tob -> 524 + 1178)
data_col = pd.read_csv(r'M:\ML_scripts\chemplot\colistin_full_labelled.csv').drop(columns=['Unnamed: 0'])        # for col -> 890 + 1146

tob_train = data[data['set'] == 'train']
tob_test = data[data['set'] == 'test']

col_train = data_col[data_col['set'] == 'train']
col_test = data_col[data_col['set'] == 'test']

# %%
sns.set_style('white')

chemplot_data = Plotter.from_smiles(data['Structure'], target=data['Class'], target_type='C', sim_type='structural');
chemplot_data.umap(random_state=42);
chemplot_data.visualize_plot(size=10, kind='scatter', title='TM-60 UMAP');

col_chemplot_data = Plotter.from_smiles(data_col['Structure'], target=data_col['Class'], target_type='C', sim_type='structural');
col_chemplot_data.umap(random_state=42);
col_chemplot_data.visualize_plot(size=10, kind='scatter', title='CM-60 UMAP');
# Out:
# c:\Users\sgjhewi2\.conda\envs\chemplot\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\sgjhewi2\.conda\envs\chemplot\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\sgjhewi2\.conda\envs\chemplot\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\sgjhewi2\.conda\envs\chemplot\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# these may not look the same as those found in the report, similar to tSNE's randomness
